# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## figure

# %%
# %matplotlib
# Out:
# Using matplotlib backend: Qt5Agg

# %%
fig, ax = plt.subplots()

# %%
x = np.arange(10)
y = x + 1
ax.plot(x, y)

# %%
fig

# %%
ax.set_xlabel('x')
# Out:
# Text(0.5, 23.192222222222206, 'x')

# %%
ax.get_lines()
# Out:
# <a list of 1 Line2D objects>

# %%
ax.get_lines()[0].set_lw(4)

# %%
fig2, ax2 = plt.subplots(2,2)

# %%
fig2

# %%
type(ax2)
# Out:
# numpy.ndarray

# %%
type(ax2[0, 0])
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %%
ax2[0,0].plot(x, y)
