# %%
from graphviz import Digraph

# %%
dot = Digraph(format='png', name='graphviz_demo', node_attr={'shape':'box'})
dot.node('1', 'jjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjj')
dot.node('2', r'kdkalkddddddddddddddddddddddddddddddk\nldjsllsdlaldllfaaaaaaa')

# %%
dot.source
# Out:
# 'digraph graphviz_demo {\n\tnode [shape=box]\n\t1 [label=jjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjj]\n\t2 [label="kdkalkddddddddddddddddddddddddddddddk\\nldjsllsdlaldllfaaaaaaa"]\n}'

# %%
print(dot.source)
# Out:
# digraph graphviz_demo {
# 	node [shape=box]
# 	1 [label=jjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjj]
# 	2 [label="kdkalkddddddddddddddddddddddddddddddk\nldjsllsdlaldllfaaaaaaa"]
# }

# %%
dot

# %%
dot.node('3', 'kldladlal?', shape='diamond')
dot.edges(['23'])
dot
